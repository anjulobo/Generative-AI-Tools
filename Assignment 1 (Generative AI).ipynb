# %%
# 1. Print an f-string that displays NLP stands for Natural Language Processing using the variables provided.

# %%
flform = "NLP"
meaning = "Natural Language Processing"
print(f"{flform} stands for {meaning}")
# Out:
# NLP stands for Natural Language Processing

# %%
 #2. Create a file in the current working directory called contacts.txt by running the cell below.

# %%
file = open("contacts.txt","w")
fields = file.write("Name, Roll No")
file.close()

print("contacts.text file has been created")
# Out:
# contacts.text file has been created

# %%
#3. Open the file and use .read() to save the contents of the file to a string called fields. Make sure the file is closed at the end.

# %%
file = open("contacts.txt","r")
feilds = file.read()
print(feilds)
file.close()
# Out:
# Name, Roll No

# %%
# 4. Use PyPDF2 to open the file Business_Proposal.pdf. Extract the text of page 2.

# %%
# !pip install PyPDF2

# %%
import PyPDF2

# %%
with open("Business_Proposal.pdf", "rb") as file:

  reader = PyPDF2.PdfReader(file)

  page2 = reader.pages[1]

  text = page2.extract_text()

print(text)
# Out:
# AUTHORS:
# Amy Baker, Finance Chair, x345, abaker@ourcompany.com
# Chris Donaldson, Accounting Dir., x621, cdonaldson@ourcompany.com
# Erin Freeman, Sr. VP, x879, efreeman@ourcompany.com

# %%
#5. Open the file contacts.txt in append mode. Add the text of page 2 from above to contacts.txt.

# %%
import PyPDF2

with open("Business_Proposal.pdf", "rb") as Pdf_file:
  reader = PyPDF2.PdfReader(Pdf_file)
  text = reader.pages[1].extract_text()

with open("contacts.txt", "a+") as file:
  file.write(text +"n")

# %%
#6. Using the page_two_text variable created above, extract any email addresses that were contained in the file Business_Proposal.pdf.

# %%
import PyPDF2
import re

with open("Business_Proposal.pdf", "rb") as Pdf_file:
   reader = PyPDF2.PdfReader(Pdf_file)
   page2_text = reader.pages[1].extract_text()

emails = re.findall(r"[a-zA=Z0-9._%+-]+@[a-zA-Z0-9.-]+\.", page2_text)

print(emails)
# Out:
# ['abaker@ourcompany.', 'cdonaldson@ourcompany.', 'efreeman@ourcompany.']
